# %% [markdown]
# <a href="https://colab.research.google.com/github/harinijs03/2023103549_SDC_assignment/blob/main/Langchainresume.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Install necessary packages
# !pip install -q langchain google-generativeai

# Step 2: Import required libraries
import os
import google.generativeai as genai
from typing import List, Optional, ClassVar
from langchain_core.language_models import LLM
from langchain_core.prompts import PromptTemplate

# Step 3: Set your Gemini API key (you said hardcoding is okay)
os.environ["GOOGLE_API_KEY"] = "AIzaSyBzeETE_HhcD7zsf0bYY4uuoiiot6jjfvw"
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

# Step 4: Create a custom Gemini 1.5 Flash wrapper for LangChain
class GeminiFlashLLM(LLM):
    model_name: ClassVar[str] = "gemini-1.5-flash"
    temperature: ClassVar[float] = 0.3

    def _call(self, prompt: str, stop: Optional[List[str]] = None) -> str:
        try:
            model = genai.GenerativeModel(self.model_name)
            response = model.generate_content(prompt)
            return response.text.strip()
        except Exception as e:
            return f"❌ Error: {str(e)}"

    @property
    def _llm_type(self) -> str:
        return "gemini-1.5-flash"

# Step 5: Define the Resume Evaluation Prompt
resume_prompt = PromptTemplate.from_template("""
You are a professional career advisor and resume reviewer. Analyze the resume content provided below and give detailed suggestions to improve the resume in terms of:

1. Structure & Formatting
2. Skills (missing or outdated)
3. Language (tone, clarity)
4. Job Alignment (how well it suits a software engineering or data science role)

Resume:
{resume_text}

Suggestions:
""".strip())

# Step 6: Create the LangChain chain
llm = GeminiFlashLLM()
resume_chain = resume_prompt | llm

# Step 7: Function to evaluate resume
def evaluate_resume(resume_text: str):
    result = resume_chain.invoke({"resume_text": resume_text})
    return result
# Example Resume Content (You can replace this with any text)
sample_resume = """
John Doe
Email: john.doe@email.com
Phone: (123) 456-7890

Summary:
Experienced software engineer with a passion for developing scalable web applications and working across the full stack.

Experience:
- Software Engineer at TechCorp (2021 - Present)
  - Built REST APIs using Flask and PostgreSQL
  - Worked on frontend features using React.js
  - Implemented CI/CD pipelines

Education:
- B.Sc. in Computer Science, University XYZ, 2018

Skills:
Python, JavaScript, React, SQL, Git, Docker
"""

# Run the analyzer
feedback = evaluate_resume(sample_resume)
print("📄 Resume Analysis & Suggestions:\n")
print(feedback)
# Out:
# 📄 Resume Analysis & Suggestions:
#
# This resume has a good foundation but needs significant improvements to be competitive for software engineering or data science roles.  Here's a detailed breakdown of suggestions:
#
# **1. Structure & Formatting:**
#
# * **Contact Information:**  Good.  Consider adding LinkedIn profile URL.
# * **Summary:** Too generic.  Instead of a summary, use a **Professional Profile** or **Objective** statement.  This should be tailored to the specific job being applied for, highlighting 1-2 key accomplishments and relevant skills.  For example:  "Results-oriented Software Engineer with 2+ years of experience building and deploying scalable web applications using Flask, React, and PostgreSQL. Proven ability to deliver high-quality code within agile development environments, contributing to significant improvements in [mention a quantifiable achievement, e.g., system performance or user engagement]."
# * **Experience:** Needs expansion.  Use the STAR method (Situation, Task, Action, Result) to describe accomplishments.  Quantify results whenever possible (e.g., "Improved API response time by 15%"). Bullet points should be action-oriented and start with strong verbs. Instead of "Built REST APIs...", try "Developed and deployed high-performance REST APIs using Flask and PostgreSQL, resulting in a 20% increase in data processing efficiency."
# * **Education:**  Fine for now, but consider adding GPA if above 3.5, relevant coursework (e.g., Machine Learning, Data Structures and Algorithms), or academic projects.
# * **Skills:** Needs organization and expansion.  Group skills into categories (e.g., Programming Languages, Databases, Frameworks, Tools, Cloud Platforms).  Add more specific skills based on the target job description.
#
#
# **2. Skills (Missing or Outdated):**
#
# The skills listed are a good starting point, but lack depth and breadth.  Depending on the target role (Software Engineer vs. Data Scientist), the following additions are crucial:
#
# * **Software Engineering:**  Consider adding skills like:
#     * **Testing Frameworks:**  JUnit, pytest, Selenium
#     * **Version Control (beyond Git):**  GitHub, GitLab, Bitbucket workflows (e.g., branching strategies, pull requests)
#     * **Cloud Platforms:** AWS, Azure, GCP (at least familiarity with one)
#     * **Agile Methodologies:** Scrum, Kanban
#     * **Design Patterns:**  Familiarity with common design patterns
#     * **Specific libraries/tools:** Depending on the role, add libraries used for specific tasks (e.g., logging libraries, message queues)
#
# * **Data Science:** If aiming for a data science role, the skills need a significant overhaul:
#     * **Programming Languages:** R (in addition to Python)
#     * **Data Manipulation/Analysis:** Pandas, NumPy, Scikit-learn
#     * **Data Visualization:** Matplotlib, Seaborn, Tableau, Power BI
#     * **Machine Learning Algorithms:** Regression, Classification, Clustering
#     * **Big Data Technologies:** Spark, Hadoop (depending on the role)
#     * **Databases (beyond SQL):** NoSQL databases like MongoDB or Cassandra
#
# **3. Language (Tone, Clarity):**
#
# The language is functional but lacks impact.  Use stronger action verbs, quantify achievements, and avoid vague statements.  The tone should be confident and professional.
#
# **4. Job Alignment (Software Engineering or Data Science):**
#
# The resume as it stands is better suited for a junior Software Engineering role.  To target a Data Science role, significant changes are needed, focusing on data manipulation, analysis, and machine learning skills. The current skills are too general for a competitive Data Science application.
#
#
# **Revised Resume Structure (Example for Software Engineering):**
#
# **John Doe**
# john.doe@email.com | (123) 456-7890 | linkedin.com/in/johndoe
#
#
# **Professional Profile:**
#
# Highly motivated and results-oriented Software Engineer with 2+ years of experience building and deploying scalable web applications. Proven ability to collaborate effectively within Agile teams, leveraging expertise in full-stack development using technologies such as React, Flask, and PostgreSQL.  Successfully improved API response time by 15% through optimization of database queries and implementation of caching mechanisms.
#
#
# **Experience:**
#
# **Software Engineer | TechCorp | 2021 – Present**
#
# * Developed and deployed high-performance REST APIs using Flask and PostgreSQL, resulting in a 20% increase in data processing efficiency.  Implemented comprehensive unit and integration tests using pytest, ensuring high code quality and stability.
# * Built and maintained responsive front-end features using React.js, improving user engagement by 10% as measured by increased session duration.
# * Implemented and maintained CI/CD pipelines using Jenkins, automating the build, testing, and deployment process and reducing deployment time by 50%.
# * Collaborated with cross-functional teams (design, product, QA) using Agile methodologies (Scrum) to deliver high-quality software on time and within budget.
#
#
# **Education:**
#
# **B.Sc. in Computer Science | University XYZ | 2018**
# * GPA: 3.7 (Optional - include if above 3.5)
# * Relevant Coursework: Data Structures and Algorithms, Database Systems, Software Engineering
#
#
# **Skills:**
#
# **Programming Languages:** Python, JavaScript, Java (Add if applicable)
# **Frameworks/Libraries:** React.js, Flask,  JUnit, pytest
# **Databases:** PostgreSQL, MySQL (Add if applicable)
# **Tools:** Git, Docker, Jenkins, AWS (or Azure/GCP – specify which)
# **Methodologies:** Agile (Scrum), CI/CD
#
#
# Remember to tailor this revised structure and the content within to each specific job description.  Focus on keywords and accomplishments relevant to the target role.  A well-crafted resume significantly increases your chances of landing an interview.
